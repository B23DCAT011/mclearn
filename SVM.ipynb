# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install liac-arff
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11728 sha256=09c092a709c9b55baa1e48f39c6e4420116821d40794ac08e5c450adb1b5fb12
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\a9\ac\cf\c2919807a5c623926d217c0a18eb5b457e5c19d242c3b5963a
# Successfully built liac-arff
# ...

# %%
import arff
with open("titanic.arff", "r") as file:
    data = arff.load(file)

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(data["data"])

# Lưu thành file CSV
df.to_csv("titanic.csv", index=False)

# %%
df = pd.read_csv("titanic.csv")

# %%
df.head()
# Out:
#      0  1                                                2       3        4  \
# 0  1.0  1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1  1.0  1                   Allison, Master. Hudson Trevor    male   0.9167
# 2  1.0  0                     Allison, Miss. Helen Loraine  female   2.0000
# 3  1.0  0             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4  1.0  0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#      5    6       7         8        9 10   11     12  \
# 0  0.0  0.0   24160  211.3375       B5  S    2    NaN
# 1  1.0  2.0  113781  151.5500  C22 C26  S   11    NaN
# 2  1.0  2.0  113781  151.5500  C22 C26  S  NaN    NaN
# 3  1.0  2.0  113781  151.5500  C22 C26  S  NaN  135.0
# 4  1.0  2.0  113781  151.5500  C22 C26  S  NaN    NaN
#
#                                 13
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1309 non-null   float64
#  1   1       1309 non-null   int64
#  2   2       1309 non-null   object
#  3   3       1309 non-null   object
#  4   4       1046 non-null   float64
#  5   5       1309 non-null   float64
#  6   6       1309 non-null   float64
#  7   7       1309 non-null   object
#  8   8       1308 non-null   float64
#  9   9       295 non-null    object
#  10  10      1307 non-null   object
#  11  11      486 non-null    object
#  12  12      121 non-null    float64
#  13  13      745 non-null    object
# dtypes: float64(6), int64(1), object(7)
# memory usage: 143.3+ KB

# %%
column_names = ["Pclass", "Survived", "Name", "Sex", "Age", "SibSp", "Parch", 
                "Ticket", "Fare", "Cabin", "Embarked", "Boat", "Body", "HomeDest"]

# Đọc file và gán tên cột
df = pd.read_csv("titanic.csv", header=None, names=column_names)

# Hiển thị dữ liệu
df.head()
# Out:
#    Pclass  Survived                                  Name     Sex      Age  \
# 0     0.0         1                                     2       3   4.0000
# 1     1.0         1         Allen, Miss. Elisabeth Walton  female  29.0000
# 2     1.0         1        Allison, Master. Hudson Trevor    male   0.9167
# 3     1.0         0          Allison, Miss. Helen Loraine  female   2.0000
# 4     1.0         0  Allison, Mr. Hudson Joshua Creighton    male  30.0000
#
#    SibSp  Parch  Ticket      Fare    Cabin Embarked Boat   Body  \
# 0    5.0    6.0       7    8.0000        9       10   11   12.0
# 1    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 2    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 3    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 4    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
#
#                           HomeDest
# 0                               13
# 1                     St Louis, MO
# ...

# %%
df.drop(['Name','Embarked','Cabin','Ticket','HomeDest','Boat','Body'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Pclass  Survived     Sex      Age  SibSp  Parch      Fare
# 0     0.0         1       3   4.0000    5.0    6.0    8.0000
# 1     1.0         1  female  29.0000    0.0    0.0  211.3375
# 2     1.0         1    male   0.9167    1.0    2.0  151.5500
# 3     1.0         0  female   2.0000    1.0    2.0  151.5500
# 4     1.0         0    male  30.0000    1.0    2.0  151.5500

# %%
df.isna().any()
# Out:
# Pclass      False
# Survived    False
# Sex         False
# Age          True
# SibSp       False
# Parch       False
# Fare         True
# dtype: bool

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#    Pclass  Survived     Sex      Age  SibSp  Parch      Fare
# 0     0.0         1       3   4.0000    5.0    6.0    8.0000
# 1     1.0         1  female  29.0000    0.0    0.0  211.3375
# 2     1.0         1    male   0.9167    1.0    2.0  151.5500
# 3     1.0         0  female   2.0000    1.0    2.0  151.5500
# 4     1.0         0    male  30.0000    1.0    2.0  151.5500

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Sex'] = le.fit_transform(df['Sex'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1046 entries, 0 to 1309
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    1046 non-null   float64
#  1   Survived  1046 non-null   int64
#  2   Sex       1046 non-null   int32
#  3   Age       1046 non-null   float64
#  4   SibSp     1046 non-null   float64
#  5   Parch     1046 non-null   float64
#  6   Fare      1046 non-null   float64
# dtypes: float64(5), int32(1), int64(1)
# memory usage: 61.3 KB

# %%
df.head()
# Out:
#    Pclass  Survived  Sex      Age  SibSp  Parch      Fare
# 0     0.0         1    0   4.0000    5.0    6.0    8.0000
# 1     1.0         1    1  29.0000    0.0    0.0  211.3375
# 2     1.0         1    2   0.9167    1.0    2.0  151.5500
# 3     1.0         0    1   2.0000    1.0    2.0  151.5500
# 4     1.0         0    2  30.0000    1.0    2.0  151.5500

# %%
y = df.iloc[:,1]
df.drop(['Survived'],axis=1,inplace=True)

# %%
X = df.iloc[:,0:]

# %%
# Out:
#       Pclass  Sex      Age  SibSp  Parch      Fare
# 0        0.0    0   4.0000    5.0    6.0    8.0000
# 1        1.0    1  29.0000    0.0    0.0  211.3375
# 2        1.0    2   0.9167    1.0    2.0  151.5500
# 3        1.0    1   2.0000    1.0    2.0  151.5500
# 4        1.0    2  30.0000    1.0    2.0  151.5500
# ...      ...  ...      ...    ...    ...       ...
# 1302     3.0    2  45.5000    0.0    0.0    7.2250
# 1305     3.0    1  14.5000    1.0    0.0   14.4542
# 1307     3.0    2  26.5000    0.0    0.0    7.2250
# 1308     3.0    2  27.0000    0.0    0.0    7.2250
# 1309     3.0    2  29.0000    0.0    0.0    7.8750
#
# [1046 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(X,y,test_size = 0.30,random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import classification_report

svm = SVC()

param_grid = {
    'C' : [0.1,1,10],
    'kernel':['linear','poly','rbf','sigmoid'],
    'degree':[2,3,4],
}

grid_search = GridSearchCV(estimator=svm,param_grid=param_grid,cv=5)
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10], 'degree': [2, 3, 4],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']})

# %%
best_param = grid_search.best_params_
best_score = grid_search.best_score_

print('best_param',best_param)
print('best_score',best_score)
# Out:
# best_param {'C': 1, 'degree': 3, 'kernel': 'poly'}
# best_score 0.7869164103997763

# %%
best_svm = SVC(**best_param)
best_svm.fit(X_train,y_train)
# Out:
# SVC(C=1, kernel='poly')

# %%
y_pred = best_svm.predict(X_test)

# %%
print('\n Classification repor on test set:')
print(classification_report(y_test,y_pred))
# Out:
#  Classification repor on test set:
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84       181
#            1       0.81      0.72      0.76       133
#
#     accuracy                           0.81       314
#    macro avg       0.81      0.80      0.80       314
# weighted avg       0.81      0.81      0.81       314
