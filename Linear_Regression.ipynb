# %%
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
# height (cm), input data, each row is a data point
X = np.array([[147, 150, 153, 158, 163, 165, 168, 170, 173, 175, 178, 180, 183]]).T
# weight (kg)
y = np.array([ 49, 50, 51, 54, 58, 59, 60, 62, 63, 64, 66, 67, 68])

# %%
# Building Xbar
one = np.ones((X.shape[0], 1))
Xbar = np.concatenate((one, X), axis = 1) # each point is one row
# Calculating weights of the fitting line
A = np.dot(Xbar.T, Xbar)
b = np.dot(Xbar.T, y)
w = np.dot(np.linalg.pinv(A), b)
# weights
w_0, w_1 = w[0], w[1]

# %%
y1 = w_1*155 + w_0
y2 = w_1*175 + w_0
print('Input 155cm, true output 52kg, predicted output %.2fkg' %(y1) )
print('Input 175cm, true output 56kg, predicted output %.2fkg' %(y2) )
# Out:
# Input 155cm, true output 52kg, predicted output 52.94kg
# Input 175cm, true output 56kg, predicted output 64.13kg

# %%
print(w)
# Out:
# [-33.73541021   0.55920496]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("homeprices.csv",sep=";")
df
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = pd.read_csv("homeprices.csv",sep=";")
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
# %matplotlib inline
plt.xlabel('area(sqr ft)')
plt.ylabel('price(USD)')
plt.scatter(df.area,df.price,color='red',marker="+")
plt.plot(df.area,reg.predict(df[['area']]),color='blue')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       2 plt.xlabel('area(sqr ft)')
#       3 plt.ylabel('price(USD)')
# ----> 4 plt.scatter(df.area,df.price,color='red',marker="+")
#       5 plt.plot(df.area,reg.predict(df[['area']]),color='blue')
#
# NameError: name 'df' is not defined

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 reg = linear_model.LinearRegression()
# ----> 2 reg.fit(df[['area']],df.price)
#
# NameError: name 'df' is not defined

# %%
value=pd.DataFrame([[3300]])
reg.predict(value)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 value=pd.DataFrame([[3300]])
# ----> 2 reg.predict(value)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:286, in LinearModel.predict(self, X)
#     272 def predict(self, X):
#     273     """
#     274     Predict using the linear model.
#     275
#    (...)
#     284         Returns predicted values.
#     285     """
# --> 286     return self._decision_function(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:267, in LinearModel._decision_function(self, X)
#     266 def _decision_function(self, X):
# --> 267     check_is_fitted(self)
#     269     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     270     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# ...

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print(reg.coef_)
#       2 print(reg.intercept_)
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
135.78767123*3300+180616.43835616432
# Out:
# 628715.7534151643

# %%
pre = pd.read_csv("predictPrice.csv")
pre
# Out:
#     area
# 0   1100
# 1   2200
# 2   5000
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   8600
# 10  7100

# %%
a=reg.predict(pre)
print(a)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 a=reg.predict(pre)
#       2 print(a)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:286, in LinearModel.predict(self, X)
#     272 def predict(self, X):
#     273     """
#     274     Predict using the linear model.
#     275
#    (...)
#     284         Returns predicted values.
#     285     """
# --> 286     return self._decision_function(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:267, in LinearModel._decision_function(self, X)
#     266 def _decision_function(self, X):
# --> 267     check_is_fitted(self)
#     269     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     270     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# ...

# %%
pre['prices']=a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 pre['prices']=a
#
# NameError: name 'a' is not defined

# %%
pre
# Out:
#     area
# 0   1100
# 1   2200
# 2   5000
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   8600
# 10  7100

# %%
pre.to_csv("predictPrice1.csv")

# %%
d=pd.read_csv('canada_per_capita_income.csv')
d
# Out:
#     year         price
# 0   1970   3399.299037
# 1   1971   3768.297935
# 2   1972   4251.175484
# 3   1973   4804.463248
# 4   1974   5576.514583
# 5   1975   5998.144346
# 6   1976   7062.131392
# 7   1977   7100.126170
# 8   1978   7247.967035
# 9   1979   7602.912681
# 10  1980   8355.968120
# 11  1981   9434.390652
# 12  1982   9619.438377
# 13  1983  10416.536590
# 14  1984  10790.328720
# 15  1985  11018.955850
# 16  1986  11482.891530
# 17  1987  12974.806620
# 18  1988  15080.283450
# 19  1989  16426.725480
# 20  1990  16838.673200
# 21  1991  17266.097690
# 22  1992  16412.083090
# 23  1993  15875.586730
# 24  1994  15755.820270
# 25  1995  16369.317250
# 26  1996  16699.826680
# 27  1997  17310.757750
# 28  1998  16622.671870
# 29  1999  17581.024140
# 30  2000  18987.382410
# 31  2001  18601.397240
# 32  2002  19232.175560
# 33  2003  22739.426280
# 34  2004  25719.147150
# 35  2005  29198.055690
# 36  2006  32738.262900
# 37  2007  36144.481220
# 38  2008  37446.486090
# ...

# %%
aa = linear_model.LinearRegression()
aa.fit(d[['year']],d.price)
# Out:
# LinearRegression()

# %%
value = pd.DataFrame([[2020]])
aa.predict(value)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('Capital(USD)')
plt.scatter(d.year,d.price,color='red',marker="+")
plt.plot(d.year,aa.predict(d[['year']]),color='blue')

# %%
df = pd.read_csv('HomePrice.csv',sep=";")
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %%
import math
median_bedrooms = math.floor(df.bedrooms.median())
median_bedrooms
# Out:
# 3

# %%
df.bedrooms = df.bedrooms.fillna(median_bedrooms)
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       3.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area','bedrooms','age']],df.price)
# Out:
# LinearRegression()

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [   137.25 -26025.    -6825.  ]
# 383724.9999999998

# %%
reg.predict([[3000,3,40]])
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([444400.])

# %%
d = pd.read_csv('hiring.csv')
d
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
d.experience = d.experience.fillna('zero')
d
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
# !pip install word2number

# %%
from word2number import w2n
d['experience'] = d['experience'].astype(str)  # Ép kiểu về string
d['experience'] = d['experience'].apply(w2n.word_to_num)
d
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    NaN                           7      72000
# 7          11                    7.0                           8      80000

# %%
median_score = math.floor(d['test_score(out of 10)'].mean())
median_score
# Out:
# 7

# %%
d['test_score(out of 10)']= d['test_score(out of 10)'].fillna(median_score)
d
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    7.0                           7      72000
# 7          11                    7.0                           8      80000

# %%
reg.fit(d[['experience','test_score(out of 10)','interview_score(out of 10)']],d['salary($)'])
# Out:
# LinearRegression()

# %%
reg.predict([[2,9,6]])
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([53713.86677124])

# %%
import pickle

# %%
with open('linear_rg','wb') as f:
    pickle.dump(reg,f)

# %%
with open('linear_rg','rb') as f:
    model =pickle.load(f)

# %%
ar = np.array(5000).reshape(-1, 1)
model.predict([[2,9,6]])
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([53713.86677124])
